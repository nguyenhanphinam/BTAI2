# %% [markdown]
# <a href="https://colab.research.google.com/github/nguyenhanphinam/BTAI2/blob/main/ProjectAI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout, Conv2D, MaxPooling2D, Flatten, LSTM, BatchNormalization
from tensorflow.keras.optimizers import Adam,SGD
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import load_img, img_to_array
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import os
from skimage import io
from tensorflow.keras.preprocessing import image

# %%
# Tạo ra class ImageDataGenerator để chỉnh sửa ảnh 
train_datagen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True)

# %%
training_data=train_datagen.flow_from_directory('/content/drive/MyDrive/projectAI/huyet_dao/train',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 810 images belonging to 7 classes.

# %%
validation_data=train_datagen.flow_from_directory('/content/drive/MyDrive/projectAI/huyet_dao/validation',target_size=(150,150), batch_size=32, class_mode='categorical')
# Out:
# Found 224 images belonging to 7 classes.

# %%
training_data.class_indices
# Out:
# {'AnDuong': 0,
#  'BachHoi': 1,
#  'NghinhHuong': 2,
#  'SuatCoc': 3,
#  'ThaiDuong': 4,
#  'ThienTru': 5,
#  'ToanTruc': 6}

# %%
model=Sequential()
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same',input_shape=(150,150,3))) # Tích chập 64 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(64,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 128 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(128,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 256 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(256,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(512,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same')) # Tích chập 512 lần với mỗi lần là 3 hàng 3 cột
model.add(Conv2D(512,(3,3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dense(512,activation='relu',kernel_initializer='he_uniform'))
model.add(Dropout(0.2))
model.add(Dense(7,activation='softmax'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 150, 150, 64)      1792
#
#  conv2d_9 (Conv2D)           (None, 150, 150, 64)      36928
#
#  max_pooling2d_4 (MaxPooling  (None, 75, 75, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 75, 75, 128)       73856
#
#  conv2d_11 (Conv2D)          (None, 75, 75, 128)       147584
#
#  max_pooling2d_5 (MaxPooling  (None, 37, 37, 128)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 37, 37, 256)       295168
#
#  conv2d_13 (Conv2D)          (None, 37, 37, 256)       590080
#
#  max_pooling2d_6 (MaxPooling  (None, 18, 18, 256)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 18, 18, 512)       1180160
#
#  conv2d_15 (Conv2D)          (None, 18, 18, 512)       2359808
#
#  max_pooling2d_7 (MaxPooling  (None, 9, 9, 512)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 41472)             0
#
#  dense_3 (Dense)             (None, 512)               21234176
#
#  dense_4 (Dense)             (None, 512)               262656
#
#  dropout_1 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 26,185,799
# Trainable params: 26,185,799
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt=SGD(lr=0.01,momentum=0.9)
model.compile(optimizer=opt,loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
history=model.fit(training_data,epochs=500,
                  batch_size=100,verbose=1, validation_data=validation_data,
                  callbacks=[EarlyStopping(monitor='val_loss', patience=30)])
# Out:
# Epoch 1/500
# 26/26 [==============================] - 10s 341ms/step - loss: 2.3460 - accuracy: 0.2222 - val_loss: 1.9037 - val_accuracy: 0.2321
# Epoch 2/500
# 26/26 [==============================] - 9s 326ms/step - loss: 1.8851 - accuracy: 0.2481 - val_loss: 1.8973 - val_accuracy: 0.2321
# Epoch 3/500
# 26/26 [==============================] - 9s 326ms/step - loss: 1.8787 - accuracy: 0.2481 - val_loss: 1.8949 - val_accuracy: 0.2321
# Epoch 4/500
# 26/26 [==============================] - 9s 326ms/step - loss: 1.8674 - accuracy: 0.2481 - val_loss: 1.8887 - val_accuracy: 0.2321
# Epoch 5/500
# 26/26 [==============================] - 9s 329ms/step - loss: 1.8462 - accuracy: 0.2494 - val_loss: 1.8422 - val_accuracy: 0.2232
# Epoch 6/500
# 26/26 [==============================] - 9s 326ms/step - loss: 1.7695 - accuracy: 0.3000 - val_loss: 1.8090 - val_accuracy: 0.2991
# Epoch 7/500
# 26/26 [==============================] - 8s 334ms/step - loss: 1.7733 - accuracy: 0.3111 - val_loss: 1.7657 - val_accuracy: 0.3080
# Epoch 8/500
# 26/26 [==============================] - 9s 330ms/step - loss: 1.6924 - accuracy: 0.3642 - val_loss: 1.6753 - val_accuracy: 0.3571
# Epoch 9/500
# 26/26 [==============================] - 9s 331ms/step - loss: 1.6898 - accuracy: 0.3654 - val_loss: 1.5806 - val_accuracy: 0.4732
# Epoch 10/500
# 26/26 [==============================] - 9s 329ms/step - loss: 1.6123 - accuracy: 0.3889 - val_loss: 1.4679 - val_accuracy: 0.4062
# Epoch 11/500
# 26/26 [==============================] - 9s 331ms/step - loss: 1.5009 - accuracy: 0.4580 - val_loss: 1.4458 - val_accuracy: 0.4330
# Epoch 12/500
# 26/26 [==============================] - 9s 330ms/step - loss: 1.4735 - accuracy: 0.4519 - val_loss: 1.2826 - val_accuracy: 0.5670
# Epoch 13/500
# 26/26 [==============================] - 9s 330ms/step - loss: 1.4161 - accuracy: 0.4765 - val_loss: 1.2423 - val_accuracy: 0.5491
# Epoch 14/500
# 26/26 [==============================] - 9s 326ms/step - loss: 1.3298 - accuracy: 0.5049 - val_loss: 1.1557 - val_accuracy: 0.5536
# Epoch 15/500
# 26/26 [==============================] - 9s 330ms/step - loss: 1.2652 - accuracy: 0.5259 - val_loss: 1.1653 - val_accuracy: 0.5848
# Epoch 16/500
# 26/26 [==============================] - 9s 327ms/step - loss: 1.1724 - accuracy: 0.5691 - val_loss: 0.9895 - val_accuracy: 0.6205
# Epoch 17/500
# 26/26 [==============================] - 9s 332ms/step - loss: 1.0983 - accuracy: 0.5864 - val_loss: 1.0621 - val_accuracy: 0.6205
# Epoch 18/500
# 26/26 [==============================] - 9s 329ms/step - loss: 1.0554 - accuracy: 0.6049 - val_loss: 0.7962 - val_accuracy: 0.6830
# Epoch 19/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.9973 - accuracy: 0.6395 - val_loss: 0.7625 - val_accuracy: 0.7232
# Epoch 20/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.8723 - accuracy: 0.6642 - val_loss: 0.6767 - val_accuracy: 0.7679
# Epoch 21/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.8407 - accuracy: 0.6914 - val_loss: 0.5940 - val_accuracy: 0.8214
# Epoch 22/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.8054 - accuracy: 0.7062 - val_loss: 0.6487 - val_accuracy: 0.7679
# Epoch 23/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.7638 - accuracy: 0.7284 - val_loss: 0.5068 - val_accuracy: 0.8304
# Epoch 24/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.6621 - accuracy: 0.7667 - val_loss: 0.5067 - val_accuracy: 0.8080
# Epoch 25/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.6268 - accuracy: 0.7543 - val_loss: 0.4282 - val_accuracy: 0.8661
# Epoch 26/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.5535 - accuracy: 0.8025 - val_loss: 0.5689 - val_accuracy: 0.8036
# Epoch 27/500
# 26/26 [==============================] - 9s 326ms/step - loss: 0.6116 - accuracy: 0.7827 - val_loss: 0.3982 - val_accuracy: 0.8482
# Epoch 28/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.5423 - accuracy: 0.8160 - val_loss: 0.5041 - val_accuracy: 0.8170
# Epoch 29/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.4806 - accuracy: 0.8296 - val_loss: 0.2344 - val_accuracy: 0.9330
# Epoch 30/500
# 26/26 [==============================] - 10s 372ms/step - loss: 0.5441 - accuracy: 0.7963 - val_loss: 0.3693 - val_accuracy: 0.8616
# Epoch 31/500
# 26/26 [==============================] - 9s 332ms/step - loss: 0.5022 - accuracy: 0.8321 - val_loss: 0.5409 - val_accuracy: 0.7902
# Epoch 32/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.4832 - accuracy: 0.8247 - val_loss: 0.2800 - val_accuracy: 0.8929
# Epoch 33/500
# 26/26 [==============================] - 9s 336ms/step - loss: 0.4261 - accuracy: 0.8519 - val_loss: 0.2687 - val_accuracy: 0.9107
# Epoch 34/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.3383 - accuracy: 0.8827 - val_loss: 0.3134 - val_accuracy: 0.8884
# Epoch 35/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.3440 - accuracy: 0.8728 - val_loss: 0.2836 - val_accuracy: 0.8750
# Epoch 36/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.3565 - accuracy: 0.8827 - val_loss: 0.2158 - val_accuracy: 0.9464
# Epoch 37/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.3116 - accuracy: 0.8963 - val_loss: 0.1389 - val_accuracy: 0.9420
# Epoch 38/500
# 26/26 [==============================] - 9s 331ms/step - loss: 0.2213 - accuracy: 0.9235 - val_loss: 0.0834 - val_accuracy: 0.9688
# Epoch 39/500
# 26/26 [==============================] - 8s 323ms/step - loss: 0.2258 - accuracy: 0.9210 - val_loss: 0.1623 - val_accuracy: 0.9464
# Epoch 40/500
# 26/26 [==============================] - 9s 331ms/step - loss: 0.2644 - accuracy: 0.9136 - val_loss: 0.2116 - val_accuracy: 0.9375
# Epoch 41/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.2456 - accuracy: 0.9123 - val_loss: 0.1164 - val_accuracy: 0.9732
# Epoch 42/500
# 26/26 [==============================] - 9s 331ms/step - loss: 0.2150 - accuracy: 0.9222 - val_loss: 0.1748 - val_accuracy: 0.9464
# Epoch 43/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.2360 - accuracy: 0.9235 - val_loss: 0.1578 - val_accuracy: 0.9643
# Epoch 44/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.2686 - accuracy: 0.9136 - val_loss: 0.1769 - val_accuracy: 0.9464
# Epoch 45/500
# 26/26 [==============================] - 9s 331ms/step - loss: 0.3694 - accuracy: 0.8802 - val_loss: 0.1909 - val_accuracy: 0.9375
# Epoch 46/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.2479 - accuracy: 0.9136 - val_loss: 0.1297 - val_accuracy: 0.9598
# Epoch 47/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.2072 - accuracy: 0.9358 - val_loss: 0.0927 - val_accuracy: 0.9688
# Epoch 48/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.1721 - accuracy: 0.9543 - val_loss: 0.1410 - val_accuracy: 0.9464
# Epoch 49/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.1574 - accuracy: 0.9519 - val_loss: 0.0688 - val_accuracy: 0.9821
# Epoch 50/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.1549 - accuracy: 0.9556 - val_loss: 0.1338 - val_accuracy: 0.9598
# Epoch 51/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.1625 - accuracy: 0.9481 - val_loss: 0.0474 - val_accuracy: 0.9866
# Epoch 52/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.1022 - accuracy: 0.9704 - val_loss: 0.0775 - val_accuracy: 0.9643
# Epoch 53/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.1633 - accuracy: 0.9494 - val_loss: 0.0662 - val_accuracy: 0.9821
# Epoch 54/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.1255 - accuracy: 0.9580 - val_loss: 0.0413 - val_accuracy: 0.9866
# Epoch 55/500
# 26/26 [==============================] - 9s 331ms/step - loss: 0.1319 - accuracy: 0.9593 - val_loss: 0.0539 - val_accuracy: 0.9777
# Epoch 56/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.1204 - accuracy: 0.9654 - val_loss: 0.0975 - val_accuracy: 0.9688
# Epoch 57/500
# 26/26 [==============================] - 9s 326ms/step - loss: 0.1296 - accuracy: 0.9543 - val_loss: 0.0802 - val_accuracy: 0.9777
# Epoch 58/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.0802 - accuracy: 0.9728 - val_loss: 0.0317 - val_accuracy: 0.9866
# Epoch 59/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.0920 - accuracy: 0.9691 - val_loss: 0.0353 - val_accuracy: 0.9911
# Epoch 60/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.0970 - accuracy: 0.9667 - val_loss: 0.0180 - val_accuracy: 0.9955
# Epoch 61/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.0870 - accuracy: 0.9753 - val_loss: 0.1234 - val_accuracy: 0.9732
# Epoch 62/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.0821 - accuracy: 0.9691 - val_loss: 0.0211 - val_accuracy: 0.9911
# Epoch 63/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.0817 - accuracy: 0.9728 - val_loss: 0.1476 - val_accuracy: 0.9643
# Epoch 64/500
# 26/26 [==============================] - 9s 326ms/step - loss: 0.1044 - accuracy: 0.9654 - val_loss: 0.0551 - val_accuracy: 0.9777
# Epoch 65/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0573 - accuracy: 0.9790 - val_loss: 0.0336 - val_accuracy: 0.9821
# Epoch 66/500
# 26/26 [==============================] - 10s 369ms/step - loss: 0.0963 - accuracy: 0.9728 - val_loss: 0.0406 - val_accuracy: 0.9911
# Epoch 67/500
# 26/26 [==============================] - 9s 326ms/step - loss: 0.0952 - accuracy: 0.9679 - val_loss: 0.0092 - val_accuracy: 0.9955
# Epoch 68/500
# 26/26 [==============================] - 9s 331ms/step - loss: 0.0533 - accuracy: 0.9802 - val_loss: 0.0331 - val_accuracy: 0.9955
# Epoch 69/500
# 26/26 [==============================] - 9s 333ms/step - loss: 0.0730 - accuracy: 0.9753 - val_loss: 0.0273 - val_accuracy: 0.9866
# Epoch 70/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.0727 - accuracy: 0.9815 - val_loss: 0.0240 - val_accuracy: 0.9911
# Epoch 71/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0658 - accuracy: 0.9741 - val_loss: 0.0189 - val_accuracy: 0.9911
# Epoch 72/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.0478 - accuracy: 0.9864 - val_loss: 0.0445 - val_accuracy: 0.9821
# Epoch 73/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.1042 - accuracy: 0.9667 - val_loss: 0.0509 - val_accuracy: 0.9955
# Epoch 74/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.1133 - accuracy: 0.9568 - val_loss: 0.0512 - val_accuracy: 0.9911
# Epoch 75/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.0990 - accuracy: 0.9654 - val_loss: 0.0492 - val_accuracy: 0.9821
# Epoch 76/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0981 - accuracy: 0.9679 - val_loss: 0.0456 - val_accuracy: 0.9732
# Epoch 77/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.0661 - accuracy: 0.9741 - val_loss: 0.0788 - val_accuracy: 0.9732
# Epoch 78/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.0978 - accuracy: 0.9654 - val_loss: 0.0863 - val_accuracy: 0.9732
# Epoch 79/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0704 - accuracy: 0.9790 - val_loss: 0.0365 - val_accuracy: 0.9821
# Epoch 80/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0351 - accuracy: 0.9864 - val_loss: 0.0444 - val_accuracy: 0.9911
# Epoch 81/500
# 26/26 [==============================] - 8s 325ms/step - loss: 0.0453 - accuracy: 0.9827 - val_loss: 0.0602 - val_accuracy: 0.9866
# Epoch 82/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.0905 - accuracy: 0.9704 - val_loss: 0.0487 - val_accuracy: 0.9911
# Epoch 83/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.0491 - accuracy: 0.9852 - val_loss: 0.0351 - val_accuracy: 0.9955
# Epoch 84/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0586 - accuracy: 0.9765 - val_loss: 0.0586 - val_accuracy: 0.9866
# Epoch 85/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.1167 - accuracy: 0.9630 - val_loss: 0.0423 - val_accuracy: 0.9777
# Epoch 86/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.1157 - accuracy: 0.9679 - val_loss: 0.0981 - val_accuracy: 0.9777
# Epoch 87/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.1077 - accuracy: 0.9679 - val_loss: 0.0945 - val_accuracy: 0.9732
# Epoch 88/500
# 26/26 [==============================] - 9s 325ms/step - loss: 0.0725 - accuracy: 0.9728 - val_loss: 0.0411 - val_accuracy: 0.9955
# Epoch 89/500
# 26/26 [==============================] - 9s 327ms/step - loss: 0.0636 - accuracy: 0.9802 - val_loss: 0.0846 - val_accuracy: 0.9777
# Epoch 90/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0922 - accuracy: 0.9691 - val_loss: 0.0485 - val_accuracy: 0.9911
# Epoch 91/500
# 26/26 [==============================] - 9s 330ms/step - loss: 0.0637 - accuracy: 0.9790 - val_loss: 0.0317 - val_accuracy: 0.9911
# Epoch 92/500
# 26/26 [==============================] - 9s 325ms/step - loss: 0.0469 - accuracy: 0.9815 - val_loss: 0.1028 - val_accuracy: 0.9732
# Epoch 93/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0457 - accuracy: 0.9864 - val_loss: 0.0340 - val_accuracy: 0.9866
# Epoch 94/500
# 26/26 [==============================] - 9s 326ms/step - loss: 0.0410 - accuracy: 0.9802 - val_loss: 0.0237 - val_accuracy: 0.9866
# Epoch 95/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0328 - accuracy: 0.9852 - val_loss: 0.0348 - val_accuracy: 0.9911
# Epoch 96/500
# 26/26 [==============================] - 9s 329ms/step - loss: 0.0410 - accuracy: 0.9877 - val_loss: 0.0165 - val_accuracy: 0.9911
# Epoch 97/500
# 26/26 [==============================] - 9s 328ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0448 - val_accuracy: 0.9955

# %%
Score=model.evaluate(validation_data,verbose=0)
print('Test loss',Score[0])
print('Test accuary', Score[1])
# Out:
# Test loss 0.020461244508624077
# Test accuary 0.9955357313156128

# %%
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title('Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epochs')
  plt.legend(['Train','Validation'])
  plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
model.save("Final_huyet_dao.h5")

# %%
model_CNN=load_model('Final_huyet_dao.h5')

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/AnDuong/z3508995763346_28b11c1d21c17a0d3440d9112d5cb683.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# AnDuong

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/BachHoi/z3509071091056_5975ba192a05bee8ed2badbab0a9adbf.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# BachHoi

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/NghinhHuong/z3508995720821_cba1d160f2497246a13a49159b019204.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# NghinhHuong

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/SuatCoc/z3509018970677_660624d7d382b437f9f3d229fa7ddcee.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# SuatCoc

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/ThaiDuong/z3509005418089_ade8d9de67937296a1a1eed45849bc3f.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# ThaiDuong

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/ThienTru/z3509637781998_f2e524402c34bb8e513f05129e577d45.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# ThienTru

# %%
img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/ToanTruc/z3508995710913_618dc322825dc8c95174c67b906a7d16.jpg',target_size=(150,150))
plt.imshow(img)
import numpy as np
img=img_to_array(img)
#img=img.reshape(1,256,256,3)
img=img.astype('float32')
img=img/255
img=np.expand_dims(img,axis=0)
result=model_CNN.predict(img)
if round(result[0][0])==1:
  prediction='AnDuong'
elif round(result[0][1])==1:
  prediction='BachHoi'
elif round(result[0][2])==1:
  prediction='NghinhHuong'
elif round(result[0][3])==1:
  prediction='SuatCoc'
elif round(result[0][4])==1:
  prediction='ThaiDuong'
elif round(result[0][5])==1:
  prediction='ThienTru'
elif round(result[0][6])==1:
  prediction='ToanTruc'
print(prediction)
# Out:
# ToanTruc

# %%
generator= ImageDataGenerator(rescale=1./255)
generator_data=generator.flow_from_directory('/content/drive/MyDrive/projectAI/huyet_dao/test',batch_size=5,shuffle=False,interpolation='lanczos')

point={0:'AnDuong',
      1:'BachHoi',
      2:'NghinhHuong',
      3:'SuatCoc',
      4:'ThaiDuong',
      5:'ThienTru',
      6:'ToanTruc',
}
  
plt.figure(figsize=(15,15))
for i in range(len(generator_data.filenames)):
    plt.subplot(5,4,i+1)
    plt.imshow(io.imread(os.path.join(generator_data.directory,generator_data.filenames[i])))
    plt.xticks([])
    plt.yticks([])
    img=load_img('/content/drive/MyDrive/projectAI/huyet_dao/test/'+generator_data.filenames[i],target_size=(150,150))
    img=img_to_array(img)
    img=img.reshape(1,150,150,3)
    img=img.astype('float')
    img=img/255
    plt.xlabel(point[np.argmax(model.predict(img))]) 
plt.show()
# Out:
# Found 16 images belonging to 7 classes.

# %%
# function to convert the JavaScript object into an OpenCV image
def js_to_image(js_reply):
  """
  Params:
          js_reply: JavaScript object containing image from webcam
  Returns:
          img: OpenCV BGR image
  """
  # decode base64 image
  image_bytes = b64decode(js_reply.split(',')[1])
  # convert bytes to numpy array
  jpg_as_np = np.frombuffer(image_bytes, dtype=np.uint8)
  # decode numpy array into OpenCV BGR image
  img = cv2.imdecode(jpg_as_np, flags=1)

  return img

# function to convert OpenCV Rectangle bounding box image into base64 byte string to be overlayed on video stream
def bbox_to_bytes(bbox_array):
  """
  Params:
          bbox_array: Numpy array (pixels) containing rectangle to overlay on video stream.
  Returns:
        bytes: Base64 image byte string
  """
  # convert array into PIL image
  bbox_PIL = PIL.Image.fromarray(bbox_array, 'RGBA')
  iobuf = io.BytesIO()
  # format bbox into png for return
  bbox_PIL.save(iobuf, format='png')
  # format return string
  bbox_bytes = 'data:image/png;base64,{}'.format((str(b64encode(iobuf.getvalue()), 'utf-8')))

  return bbox_bytes

# %%
from IPython.display import display, Javascript, Image
# JavaScript to properly create our live video stream using our webcam as input

def video_stream():
  js = Javascript('''
    var video;
    var div = null;
    var stream;
    var captureCanvas;
    var imgElement;
    var labelElement;
    
    var pendingResolve = null;
    var shutdown = false;
    
    function removeDom() {
       stream.getVideoTracks()[0].stop();
       video.remove();
       div.remove();
       video = null;
       div = null;
       stream = null;
       imgElement = null;
       captureCanvas = null;
       labelElement = null;
    }
    
    function onAnimationFrame() {
      if (!shutdown) {
        window.requestAnimationFrame(onAnimationFrame);
      }
      if (pendingResolve) {
        var result = "";
        if (!shutdown) {
          captureCanvas.getContext('2d').drawImage(video, 0, 0, 640, 480);
          result = captureCanvas.toDataURL('image/jpeg', 0.8)
        }
        var lp = pendingResolve;
        pendingResolve = null;
        lp(result);
      }
    }
    
    async function createDom() {
      if (div !== null) {
        return stream;
      }

      div = document.createElement('div');
      div.style.border = '2px solid black';
      div.style.padding = '3px';
      div.style.width = '100%';
      div.style.maxWidth = '600px';
      document.body.appendChild(div);
      
      const modelOut = document.createElement('div');
      modelOut.innerHTML = "<span>Status:</span>";
      labelElement = document.createElement('span');
      labelElement.innerText = 'No data';
      labelElement.style.fontWeight = 'bold';
      modelOut.appendChild(labelElement);
      div.appendChild(modelOut);
           
      video = document.createElement('video');
      video.style.display = 'block';
      video.width = div.clientWidth - 6;
      video.setAttribute('playsinline', '');
      video.onclick = () => { shutdown = true; };
      stream = await navigator.mediaDevices.getUserMedia(
          {video: { facingMode: "environment"}});
      div.appendChild(video);

      imgElement = document.createElement('img');
      imgElement.style.position = 'absolute';
      imgElement.style.zIndex = 1;
      imgElement.onclick = () => { shutdown = true; };
      div.appendChild(imgElement);
      
      const instruction = document.createElement('div');
      instruction.innerHTML = 
          '<span style="color: red; font-weight: bold;">' +
          'Bấm vào video để dừng</span>';
      div.appendChild(instruction);
      instruction.onclick = () => { shutdown = true; };
      
      video.srcObject = stream;
      await video.play();

      captureCanvas = document.createElement('canvas');
      captureCanvas.width = 640; //video.videoWidth;
      captureCanvas.height = 480; //video.videoHeight;
      window.requestAnimationFrame(onAnimationFrame);
      
      return stream;
    }
    async function stream_frame(label, imgData) {
      if (shutdown) {
        removeDom();
        shutdown = false;
        return '';
      }

      var preCreate = Date.now();
      stream = await createDom();
      
      var preShow = Date.now();
      if (label != "") {
        labelElement.innerHTML = label;
      }
            
      if (imgData != "") {
        var videoRect = video.getClientRects()[0];
        imgElement.style.top = videoRect.top + "px";
        imgElement.style.left = videoRect.left + "px";
        imgElement.style.width = videoRect.width + "px";
        imgElement.style.height = videoRect.height + "px";
        imgElement.src = imgData;
      }
      
      var preCapture = Date.now();
      var result = await new Promise(function(resolve, reject) {
        pendingResolve = resolve;
      });
      shutdown = false;
      
      return {'create': preShow - preCreate, 
              'show': preCapture - preShow, 
              'capture': Date.now() - preCapture,
              'img': result};
    }
    ''')

  display(js)
  
def video_frame(label, bbox):
  data = eval_js('stream_frame("{}", "{}")'.format(label, bbox))
  return data

# %%
# %cd /content
from google.colab.output import eval_js
from google.colab.patches import cv2_imshow
from base64 import b64decode, b64encode
import numpy as np
import PIL
import io
import cv2
from keras.models import  load_model

# start streaming video from webcam
video_stream()
# label for video
label_html = 'Đang lấy hình ảnh...'
# initialze bounding box to empty
bbox = ''
count = 0 

# Load model Nhận diện tiền
model_file_path = "Final_huyet_dao.h5"
vggmodel = load_model(model_file_path)

classes = ['AnDuong','BachHoi','NghinhHuong','SuatCoc','ThaiDuong','ThienTru','ToanTruc']
while True:
    # Đọc ảnh trả về từ JS
    js_reply = video_frame(label_html, bbox)
    if not js_reply:
        break

    # convert JS response to OpenCV Image
    frame = js_to_image(js_reply["img"])

    # Resize để đưa vào model
    frame_p = cv2.resize(frame, dsize=(150,150))
    tensor = np.expand_dims(frame_p, axis=0)

    # Feed vào mạng
    pred = vggmodel.predict(tensor)
    class_id = np.argmax(pred)
    class_name = classes[class_id]

    # Vẽ lên một ảnh để tẹo nữa overlay

    # create transparent overlay for bounding box
    bbox_array = np.zeros([480,640,4], dtype=np.uint8)
   
    bbox_array = cv2.putText(bbox_array, "{}".format(class_name),
                        (10, 20), cv2.FONT_HERSHEY_SIMPLEX, 0.5,
                        (0, 255,0), 2)

    bbox_array[:,:,3] = (bbox_array.max(axis = 2) > 0 ).astype(int) * 255
    # convert overlay of bbox into bytes
    bbox_bytes = bbox_to_bytes(bbox_array)
    # update bbox so next frame gets new overlay
    bbox = bbox_bytes
# Out:
# /content
